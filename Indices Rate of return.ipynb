# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
tickers = ['^GSPC','^IXIC','^GDAXI']
ind_data = pd.DataFrame()
for t in tickers:
    ind_data[t]= wb.DataReader(t, data_source= 'yahoo', start='1997-1-1')['Adj Close']

# %%
ind_data.head()
# Out:
#                  ^GSPC        ^IXIC       ^GDAXI
# Date
# 1996-12-31  740.739990  1291.030029          NaN
# 1997-01-02  737.010010  1280.699951  2820.810059
# 1997-01-03  748.030029  1310.680054  2863.260010
# 1997-01-06  747.650024  1316.400024  2890.199951
# 1997-01-07  753.229980  1327.729980  2876.340088

# %%
(ind_data/ind_data.iloc[0]*100).plot(figsize=(15,6));
plt.show()

# %%
ind_returns = (ind_data/ind_data.shift(1))-1
ind_returns.tail()
# Out:
#                ^GSPC     ^IXIC    ^GDAXI
# Date
# 2020-12-01  0.011271  0.012819  0.006857
# 2020-12-02  0.001791 -0.000465 -0.005161
# 2020-12-03 -0.000624  0.002252 -0.004535
# 2020-12-04  0.008836  0.007033  0.003478
# 2020-12-07 -0.001936  0.004470 -0.002102

# %%
annual_ind_returns = ind_returns.mean()*250
annual_ind_returns
# Out:
# ^GSPC     0.086130
# ^IXIC     0.126122
# ^GDAXI    0.077912
# dtype: float64
